# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
WithoutDist1=pd.read_csv("https://raw.githubusercontent.com/sayedul79/python-control-system/main/dataset/exp5-kp1-without-disturbance-group-3.csv")
WithoutDist1.head()
# Out:
#    TimeStamp  Reference   Speed   Current    Voltage      Error  Kp x Error  \
# 0       1.42  30.000763  11.125  3.347967  16.719284  18.901350   18.901350
# 1       1.43  30.000763  11.250  3.278877  16.638928  18.770123   18.770123
# 2       1.44  30.000763  11.250  3.163728  16.584770  18.770123   18.770123
# 3       1.45  30.000763  11.250  3.186758  16.622919  18.770123   18.770123
# 4       1.46  30.000763  11.250  3.324937  16.633478  18.770123   18.770123
#
#    Error Sum / Ti  Td x Delta Err.  PID Output
# 0        0.001526         0.001526   18.901350
# 1        0.001526         0.001526   18.770123
# 2        0.001526         0.001526   18.770123
# 3        0.001526         0.001526   18.770123
# 4        0.001526         0.001526   18.770123

# %%
WithoutDist_rm0=WithoutDist1[~(WithoutDist1==0)]
plt.plot(WithoutDist_rm0.TimeStamp, WithoutDist_rm0.Speed)

# %%
WithoutDist_half1=WithoutDist_rm0[(WithoutDist_rm0.TimeStamp>=8) & (WithoutDist_rm0.TimeStamp<10)]
WithoutDist_half1["TimeShift"]=WithoutDist_half1.TimeStamp-8
plt.plot(WithoutDist_half1.TimeShift, WithoutDist_half1.Speed)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4208\1889921246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WithoutDist_half1["TimeShift"]=WithoutDist_half1.TimeStamp-8

# %%
WithoutDist2=pd.read_csv("https://raw.githubusercontent.com/sayedul79/python-control-system/main/dataset/exp5-kp2-without-disturbance-group-3.csv")
WithoutDist2_rm0=WithoutDist2[~(WithoutDist2==0)]
WithoutDist_half2=WithoutDist2_rm0[(WithoutDist2_rm0.TimeStamp>=100) & (WithoutDist2_rm0.TimeStamp<102)]
WithoutDist_half2["TimeShift"]=WithoutDist_half2.TimeStamp-100
plt.plot(WithoutDist_half2.TimeShift, WithoutDist_half2.Speed)
plt.plot(WithoutDist_half1.TimeShift, WithoutDist_half1.Speed)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4208\82558691.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WithoutDist_half2["TimeShift"]=WithoutDist_half2.TimeStamp-100
